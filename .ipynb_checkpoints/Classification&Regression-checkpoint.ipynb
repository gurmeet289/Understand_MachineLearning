# %% [markdown]
# # ##Basic to understand Classification and Regression

# %% [markdown]
# ![TreeOfSV.png](attachment:TreeOfSV.png)

# %% [markdown]
# ![Classification.jpg](attachment:Classification.jpg)

# %% [markdown]
# ![Regression.jpg](attachment:Regression.jpg)
